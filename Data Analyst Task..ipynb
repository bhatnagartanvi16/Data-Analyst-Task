# %%
try:
    import pandas as pd
    import numpy as np
except:
    print('Error in importing the files.')

# %%
f_path='Sample Data - Data Analyst Task.xlsx'
try:
    df_orders=pd.read_excel(f_path,'Orders')
    df_returns=pd.read_excel(f_path,'Orders Returns')
    df_sp     =pd.read_excel(f_path,'Person')
    
except:
    print('There was an error loading the data')
# Out:
# There was an error loading the data

# %%
df_orders.head()
# Out:
#          Order ID Order Date Customer Wanted date Last Actual Ship Date  \
# 0  CA-2016-152156 2016-11-08           2016-11-11            2016-11-11
# 1  CA-2016-152156 2016-11-08           2016-11-11            2016-11-11
# 2  CA-2016-138688 2016-06-12           2016-06-16            2016-06-16
# 3  US-2015-108966 2015-10-11           2015-10-14            2015-10-18
# 4  US-2015-108966 2015-10-11           2015-10-15            2015-10-18
#
#   Customer ID    Customer Name    Segment        Country             City  \
# 0    CG-12520      Claire Gute   Consumer  United States        Henderson
# 1    CG-12520      Claire Gute   Consumer  United States        Henderson
# 2    DV-13045  Darrin Van Huff  Corporate  United States      Los Angeles
# 3    SO-20335   Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 4    SO-20335   Sean O'Donnell   Consumer  United States  Fort Lauderdale
#
#         State  Postal Code Region       Product ID         Category  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Order ID               9994 non-null   object
#  1   Order Date             9994 non-null   datetime64[ns]
#  2   Customer Wanted date   9994 non-null   datetime64[ns]
#  3   Last Actual Ship Date  9994 non-null   datetime64[ns]
#  4   Customer ID            9994 non-null   object
#  5   Customer Name          9994 non-null   object
#  6   Segment                9994 non-null   object
#  7   Country                9994 non-null   object
#  8   City                   9994 non-null   object
#  9   State                  9994 non-null   object
#  10  Postal Code            9994 non-null   int64
#  11  Region                 9994 non-null   object
#  12  Product ID             9994 non-null   object
#  13  Category               9994 non-null   object
# ...

# %% [markdown]
# ### Now what is churn ?
# #### Churn basically means the rate of attrition. That goes to say finding out the rate at which customers stop doing business with you

# %% [markdown]
# ### List of questions::
# #### 1.Find out how many shipments are reachinglate to the customer?
# #### 2.Find out on which sector of the products are we incurring a loss?
# #### 3.Finding a correlation between the above two events
# #### 4.Find if a particular category or sub-category of products are late in shipment?
# #### 5.Segmentation of customers into three segments, i.e one-time buyers, middle spenders, high spenders, or recurring customers.
# #### 6.Revenue generation based on state.
# #### 7.What will be the next year's performance.
# #### 8.Find out if there is a relation between late shipment and customer leaving/

# %%
#Find out how many shipments are reaching late to the customers?
#So here we need to work with these three columns Order Date Customer Wanted
#date Last Actual shipment date:

df_lateship=df[df["Last Actual Ship Date"]>df['Customer Wanted date']]

df_lateship['DaysLate']=df['Last Actual Ship Date']-df['Customer Wanted date']

df_lateship['DaysLate'].describe()

#Here we can see that on an avg shipment, if delayed is 1 day late
#But on the contrary amongs 9994 values, 2273 are in late shipments
#Meanding almost 20% of the shipments are arriving late.
# Out:
# C:\Users\Ananya Bhatnagar\anaconda3\lib\site-packages\ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# count                      2273
# mean     1 days 14:34:53.796744
# std      0 days 19:31:35.294663
# min             1 days 00:00:00
# 25%             1 days 00:00:00
# 50%             1 days 00:00:00
# 75%             2 days 00:00:00
# max             4 days 00:00:00
# Name: DaysLate, dtype: object

# %%
#no of rows:
a=df.index
b=len(a)
print(b)
# Out:
# 9994

# %%
#Percentage of late shipments:
# describe() m pehla hi total count hai
lateship_pct=df_lateship['DaysLate'].describe()[0]/len(df.index)*100
print('{:.2f}% of shipments are arriving late'.format(lateship_pct))
# Out:
# 22.74% of shipments are arriving late

# %%
#Lets now list out the categories and their counts:

df_orders.groupby('Category').count()
# Out:
#                  Order ID  Order Date  Customer Wanted date  \
# Category
# Furniture            2121        2121                  2121
# Office Supplies      6026        6026                  6026
# Technology           1847        1847                  1847
#
#                  Last Actual Ship Date  Customer ID  Customer Name  Segment  \
# Category
# Furniture                         2121         2121           2121     2121
# Office Supplies                   6026         6026           6026     6026
# Technology                        1847         1847           1847     1847
#
#                  Country  City  State  Postal Code  Region  Product ID  \
# Category
# Furniture           2121  2121   2121         2121    2121        2121
# Office Supplies     6026  6026   6026         6026    6026        6026
# Technology          1847  1847   1847         1847    1847        1847
#
#                  Sub-Category  Product Name  Sales  Quantity  Discount  Profit
# Category
# ...

# %%
# Find out which sector of the products are we incuring a loss
#Here we need to work with the Profit, Category & sub category of the product.

df_catloss=df[['Category','Sub-Category']].loc[df['Profit']<0].groupby('Category').count()

# %%
df_catloss
# Out:
#                  Sub-Category
# Category
# Furniture                 714
# Office Supplies           886
# Technology                271

# %%
v=df_catloss.loc['Furniture','Sub-Category']
v
#in furniture 714 ka loss hua total me se
# Out:
# 714
